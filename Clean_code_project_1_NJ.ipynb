# %% [markdown]
# # Challenge 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Loading data

# %%
file_path = 'Mta_2019_df.pickle'

mta_df = pd.read_pickle(file_path)

mta_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  16:00:00
#
#          DESC  ENTRIES  \
# 0     REGULAR  6980704
# 1  RECOVR AUD  6980727
# 2  RECOVR AUD  6980747
# 3     REGULAR  6980855
# 4     REGULAR  6981109
#
#    EXITS
# 0                                            2367517
# 1                                            2367519
# 2                                            2367546
# 3                                            2367610
# 4                                            2367667

# %% [markdown]
# ## Stripping spaces from column names

# %%
mta_df.columns = [column.strip() for column in mta_df.columns]

# %% [markdown]
# ## Trying dividing up all stations by line (result is that station names are station-line)

# %% [markdown]
# Not doing this for now...

# %%
# mta_df['STATION'] = mta_df['STATION'] + '  ' + mta_df['LINENAME']

# mta_df['STATION'] = [name.strip() for name in mta_df['STATION']]

# mta_df.head()

# %% [markdown]
# ## Dividing up 23rd street station

# %%
df_23_ST = mta_df[mta_df['STATION'] == '23 ST']

# adding line names to 23rd st station

df_23_ST['STATION'] = df_23_ST['STATION'] + '  ' + df_23_ST['LINENAME']

# All the other stations

filt_NOT_23ST = mta_df.loc[mta_df['STATION'] != '23 ST']
filt_NOT_23ST

# Putting the two back together

mta_df = pd.concat([filt_NOT_23ST, df_23_ST])
mta_df.head()
# Out:
# <ipython-input-47-0de99fa5d696>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23_ST['STATION'] = df_23_ST['STATION'] + '  ' + df_23_ST['LINENAME']
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  16:00:00
#
#          DESC  ENTRIES    EXITS
# 0     REGULAR  6980704  2367517
# 1  RECOVR AUD  6980727  2367519
# 2  RECOVR AUD  6980747  2367546
# 3     REGULAR  6980855  2367610
# 4     REGULAR  6981109  2367667

# %% [markdown]
# # Challenge 2

# %% [markdown]
# ## Adding date_time column

# %%
# mta_df["DATETIME"] = pd.to_datetime(mta_df['DATE'] + ' ' + mta_df['TIME'])

mta_df["DATETIME"] = pd.to_datetime(mta_df["DATE"] + " " + mta_df["TIME"], format="%m/%d/%Y %H:%M:%S")

mta_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  16:00:00
#
#          DESC  ENTRIES    EXITS            DATETIME
# 0     REGULAR  6980704  2367517 2019-03-16 00:00:00
# 1  RECOVR AUD  6980727  2367519 2019-03-16 04:00:00
# 2  RECOVR AUD  6980747  2367546 2019-03-16 08:00:00
# 3     REGULAR  6980855  2367610 2019-03-16 12:00:00
# 4     REGULAR  6981109  2367667 2019-03-16 16:00:00

# %% [markdown]
# # Challenge 3

# %% [markdown]
# ## Adding turnstile column

# %%
# Adding turnstile column

mta_df['TURNSTILE'] = mta_df['C/A'] + ' ' + mta_df['UNIT'] + ' ' + mta_df['SCP'] + ' ' + mta_df['STATION']

mta_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/16/2019  16:00:00
#
#          DESC  ENTRIES    EXITS            DATETIME                 TURNSTILE
# 0     REGULAR  6980704  2367517 2019-03-16 00:00:00  A002 R051 02-00-00 59 ST
# 1  RECOVR AUD  6980727  2367519 2019-03-16 04:00:00  A002 R051 02-00-00 59 ST
# 2  RECOVR AUD  6980747  2367546 2019-03-16 08:00:00  A002 R051 02-00-00 59 ST
# 3     REGULAR  6980855  2367610 2019-03-16 12:00:00  A002 R051 02-00-00 59 ST
# 4     REGULAR  6981109  2367667 2019-03-16 16:00:00  A002 R051 02-00-00 59 ST

# %%
# Checking that turnstile combos are really unique:

(mta_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATETIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(15)
# Out:
#            C/A  UNIT       SCP          STATION            DATETIME  ENTRIES
# 1093003   N306  R017  00-00-01  LEXINGTON AV/53 2019-05-23 04:00:00        2
# 912822   N120A  R153  01-05-01         UTICA AV 2019-05-19 13:00:00        2
# 1177826   N330  R202  00-00-02  63 DR-REGO PARK 2019-05-23 12:00:00        2
# 1177827   N330  R202  00-00-02  63 DR-REGO PARK 2019-05-23 16:00:00        2
# 1177828   N330  R202  00-00-02  63 DR-REGO PARK 2019-05-23 20:00:00        2
# 912813   N120A  R153  01-05-01         UTICA AV 2019-05-18 01:00:00        2
# 912814   N120A  R153  01-05-01         UTICA AV 2019-05-18 05:00:00        2
# 912815   N120A  R153  01-05-01         UTICA AV 2019-05-18 09:00:00        2
# 912816   N120A  R153  01-05-01         UTICA AV 2019-05-18 13:00:00        2
# 912817   N120A  R153  01-05-01         UTICA AV 2019-05-18 17:00:00        2
# 912818   N120A  R153  01-05-01         UTICA AV 2019-05-18 21:00:00        2
# 912819   N120A  R153  01-05-01         UTICA AV 2019-05-19 01:00:00        2
# 912820   N120A  R153  01-05-01         UTICA AV 2019-05-19 05:00:00        2
# 912821   N120A  R153  01-05-01         UTICA AV 2019-05-19 09:00:00        2
# 912823   N120A  R153  01-05-01         UTICA AV 2019-05-19 17:00:00        2

# %%
# Remove duplicates

mta_df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATETIME"], 
                          inplace=True, ascending=False)

mta_df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATETIME"], inplace=True)

mta_df.head(50)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 207476  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/21/2019
# 207475  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/21/2019
# 207474  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/21/2019
# 207473  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/21/2019
# 207472  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/21/2019
# 207471  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/21/2019
# 207470  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/20/2019
# 207469  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/20/2019
# 207468  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/20/2019
# 207467  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/20/2019
# 207466  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/20/2019
# 207465  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/20/2019
# 207464  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/19/2019
# 207463  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/19/2019
# 207462  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/19/2019
# 207461  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/19/2019
# 207460  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/19/2019
# 207459  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/19/2019
# 207458  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207457  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207456  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207455  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207454  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207453  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207452  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/18/2019
# 207451  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/17/2019
# 207450  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/17/2019
# 207449  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/17/2019
# 207448  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/17/2019
# 207447  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/17/2019
# 207446  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/17/2019
# 207445  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/16/2019
# 207444  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/16/2019
# 207443  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/16/2019
# 207442  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/16/2019
# 207441  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/16/2019
# 207440  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/16/2019
# 207439  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/15/2019
# 207438  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/15/2019
# 207437  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/15/2019
# 207436  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/15/2019
# 207435  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/15/2019
# 207434  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/15/2019
# 204933  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/14/2019
# 204932  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/14/2019
# 204931  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/14/2019
# 204930  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/14/2019
# 204929  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/14/2019
# 204928  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/14/2019
# 204927  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06
TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207475  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207474  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207473  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207472  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207471  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207470  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207469  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207468  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207467  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207466  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207465  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207464  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207463  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207462  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207461  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207460  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207459  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207458  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207457  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207456  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207455  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207454  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207453  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207452  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207451  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207450  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207449  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207448  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207447  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207446  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207445  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207444  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207443  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207442  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207441  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207440  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207439  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207438  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207437  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207436  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207435  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 207434  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204933  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204932  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204931  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204930  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204929  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204928  TRAM2 R469 00-05-01 RIT-ROOSEVELT
# 204927  TRAM2 R469 00-05-01 RIT-ROOSEVELT

# %%
turnstiles_daily = (mta_df
                        .groupby(["DATE", "TURNSTILE", ],as_index=False)
                        .ENTRIES.first())

# turnstiles_overall = (mta_df
#                         .groupby(["TURNSTILE", "DATE", "DATETIME"],as_index=False)
#                         .sum())

mta_daily = (mta_df
                        .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"],as_index=False)  #do not group by turnstile!! That will screw up box plot later
                        .ENTRIES.first())

# %% [markdown]
# ## Adding previous date and entries columns

# %%
mta_daily[["PREV_DATE", "PREV_ENTRIES"]] = (mta_daily
                                                .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE", "ENTRIES"]
                                                .apply(lambda grp: grp.shift(1)))
# Out:
# <ipython-input-53-a8c68b31b527>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mta_daily[["PREV_DATE", "PREV_ENTRIES"]] = (mta_daily

# %%
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 0  A002  R051  02-00-00   59 ST  03/16/2019  6981415         NaN           NaN
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019     6981415.0
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019     6982038.0
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019     6983420.0
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019     6984921.0

# %% [markdown]
# ## Drop the rows for the earliest date in the df

# %%
mta_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  PREV_ENTRIES
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019     6981415.0
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019     6982038.0
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019     6983420.0
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019     6984921.0
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019     6986504.0

# %% [markdown]
# ## Counters in reverse?

# %%
mta_daily[mta_daily["ENTRIES"] < mta_daily["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP          STATION        DATE     ENTRIES  \
# 7653  A025  R023  01-03-01  34 ST-HERALD SQ  03/17/2019  1238616553
# 7654  A025  R023  01-03-01  34 ST-HERALD SQ  03/18/2019  1238612634
# 7655  A025  R023  01-03-01  34 ST-HERALD SQ  03/19/2019  1238608594
# 7656  A025  R023  01-03-01  34 ST-HERALD SQ  03/20/2019  1238604518
# 7657  A025  R023  01-03-01  34 ST-HERALD SQ  03/21/2019  1238600427
#
#        PREV_DATE  PREV_ENTRIES
# 7653  03/16/2019  1.238619e+09
# 7654  03/17/2019  1.238617e+09
# 7655  03/18/2019  1.238613e+09
# 7656  03/19/2019  1.238609e+09
# 7657  03/20/2019  1.238605e+09

# %% [markdown]
# ## Let's see how many stations have this problem

# %%
(mta_daily[mta_daily["ENTRIES"] < mta_daily["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
# 446 452271.0
# 266 1428035637.0
# 1208 89575.0
# 1548 12368801.0
# 1063615462 10133831.0
# 1055323910 1063615462.0
# 141 5213587.0
# 1361 3603208.0
# 314836087 4094392.0
# 4059 1557847.0
# 148 6333363.0
# 11 5651802.0
# 2319 789868.0
# 30933984 6069289.0
# 323 7193764.0
# 115 12739117.0
# 1675 102075.0
# 2097088678 8585102.0
# 25413446 2097052080.0
# 1121 6546757.0
# 16797438 92859.0
# 98923 16811372.0
# 753 113485.0
# 16779383 81078.0
# 637574735 2502638.0
# 231 637595544.0
# 1442822323 11149972.0
# 68859001 436510383.0
# 5389855 325782.0
# 329116 5389855.0
# 2849292 3203620.0
# 3207159 2849292.0
# 12191217 15466087.0
# 15470541 12191217.0
# 1511861 144337.0
# 149612 1511861.0
# 229 593559.0
# 607126675 594262.0
# 370 274488.0
# 140397276 1577638216.0
# 458752 100663296.0
# 330 203977549.0
# 452993419 1830432.0
# 881624125 1942744055.0
# 88839862 1258666036.0
# 704681758 2758310.0
# 119 7480347.0
# 774 3000575.0
# 683737068 458752.0
# 905996399 3558247.0
# 983 1430717.0
# 659 648276.0
# 787682 659.0
# 16 2740067.0
# 2013307514 1933604.0
# 184609880 740835.0
# 154 1081620.0
# 3 5176463.0
# 190 12064667.0
# 574 414655.0
# 1715 13653626.0
# 345 2876591.0
# 13396 1905657.0
# 589954 67610294.0
# 2301788 592439.0
# 401 2301788.0
# 528 166336.0
# 59 1526472.0
# 500 374872.0
# 183 1488278.0
# 1077 10993087.0
# 478 6720818.0
# 182 10462950.0
# 2063649350 8123276.0
# 1129054802 2501541.0

# %%
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES
# 1     6981415.0          623.0
# 2     6982038.0         1382.0
# 3     6983420.0         1501.0
# 4     6984921.0         1583.0
# 5     6986504.0         1488.0

# %% [markdown]
# ## Examine distribution

# %%
sns.distplot(mta_daily['DAILY_ENTRIES']
             [mta_daily['DAILY_ENTRIES'] < 20000])
# Out:
# /Users/noah/opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DAILY_ENTRIES', ylabel='Density'>

# %% [markdown]
# ## First get daily entries by station

# %%
stations_daily = \
(mta_daily.groupby(['STATION','DATE'])['DAILY_ENTRIES'].sum()
                 .reset_index())

stations_daily.head()
# Out:
#   STATION        DATE  DAILY_ENTRIES
# 0    1 AV  03/17/2019            2.0
# 1    1 AV  03/18/2019        16141.0
# 2    1 AV  03/19/2019        19515.0
# 3    1 AV  03/20/2019        19885.0
# 4    1 AV  03/21/2019        20484.0

# %% [markdown]
# ## Filter outliers (200k)

# %%
# outlier_mask = (mta_daily['DAILY_ENTRIES']<=10000)
# stations_daily = mta_daily[outlier_mask]

# stations_daily.head()

# %% [markdown]
# ## Then get top 10 stations by daily volume

# %%
# (sum across all days is a reasonable way to define this)
top10_stations = \
    (stations_daily.groupby(['STATION'])['DAILY_ENTRIES'].sum()
                   .reset_index()
                   .sort_values(by='DAILY_ENTRIES',ascending=False) 
                   .STATION.head(10))

top10_stations
# Out:
# 65      34 ST-PENN STA
# 237    GRD CNTRL-42 ST
# 63     34 ST-HERALD SQ
# 72     42 ST-PORT AUTH
# 14      14 ST-UNION SQ
# 357     TIMES SQ-42 ST
# 230          FULTON ST
# 114              86 ST
# 9               125 ST
# 177           CANAL ST
# Name: STATION, dtype: object

# %% [markdown]
# ## Next create a new df that filters the stations daily data down to the top 10

# %%
station_daily_top10 = \
    stations_daily[stations_daily['STATION'].isin(top10_stations)].sort_values(by = 'DAILY_ENTRIES', ascending = False)

# %%
station_daily_top10.head()
# Out:
#              STATION        DATE  DAILY_ENTRIES
# 6387  34 ST-PENN STA  06/13/2019       184813.0
# 6366  34 ST-PENN STA  05/23/2019       184058.0
# 6392  34 ST-PENN STA  06/18/2019       183425.0
# 6394  34 ST-PENN STA  06/20/2019       182547.0
# 6357  34 ST-PENN STA  05/14/2019       181209.0

# %% [markdown]
# ## Plot top 10

# %%
sns.boxplot(x='DAILY_ENTRIES', y='STATION', data=station_daily_top10);

# %% [markdown]
# ### Note: Changing stations to stations + line (see above) changes this fig a bit. Is this what we want?

# %% [markdown]
# # Challenge 4

# %%
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES
# 1     6981415.0          623.0
# 2     6982038.0         1382.0
# 3     6983420.0         1501.0
# 4     6984921.0         1583.0
# 5     6986504.0         1488.0

# %%
# by turnstile with daily entries

# mta_daily.groupby(['C/A', 'UNIT', 'SCP', 'STATION'])['DAILY_ENTRIES'].sum().reset_index()

mta_daily['TURNSTILE'] = mta_daily['C/A'] + ' ' + mta_daily['UNIT'] + ' ' + mta_daily['SCP'] + ' ' + mta_daily['STATION']

mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES                 TURNSTILE
# 1     6981415.0          623.0  A002 R051 02-00-00 59 ST
# 2     6982038.0         1382.0  A002 R051 02-00-00 59 ST
# 3     6983420.0         1501.0  A002 R051 02-00-00 59 ST
# 4     6984921.0         1583.0  A002 R051 02-00-00 59 ST
# 5     6986504.0         1488.0  A002 R051 02-00-00 59 ST

# %%
mta_daily['TURNSTILE'].value_counts()
# Out:
# R422 R428 00-05-00 BUHRE AV          97
# N500 R020 00-00-01 47-50 STS ROCK    97
# B028 R136 01-00-01 SHEEPSHEAD BAY    97
# N120 R153 00-00-00 UTICA AV          97
# B031 R172 01-06-00 BRIGHTON BEACH    97
#                                      ..
# N071 R013 00-03-04 34 ST-PENN STA     1
# N071 R013 00-03-02 34 ST-PENN STA     1
# N071 R013 00-03-03 34 ST-PENN STA     1
# N071 R013 00-03-05 34 ST-PENN STA     1
# PTH19 R549 02-02-08 NEWARK C          1
# Name: TURNSTILE, Length: 4907, dtype: int64

# %%
# Getting a single turnstile

mask = mta_daily['TURNSTILE'] == 'A002 R051 02-00-00 59 ST' # does not work with station names being station+line

# mask = mta_daily['TURNSTILE']=='R116 R030 00-06-00 CHAMBERS ST  123'  # use this if organizing by station+line

one_turn = mta_daily[mask]

one_turn.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES                 TURNSTILE
# 1     6981415.0          623.0  A002 R051 02-00-00 59 ST
# 2     6982038.0         1382.0  A002 R051 02-00-00 59 ST
# 3     6983420.0         1501.0  A002 R051 02-00-00 59 ST
# 4     6984921.0         1583.0  A002 R051 02-00-00 59 ST
# 5     6986504.0         1488.0  A002 R051 02-00-00 59 ST

# %%
# Making new grouped frame by day

one_turn_daily = one_turn.groupby(['TURNSTILE', 'DATE'])['DAILY_ENTRIES'].sum().reset_index()

# one_turn_daily = one_turn.groupby(['TURNSTILE', 'DATE'])['DAILY_ENTRIES'].sum().reset_index()


one_turn_daily.head()
# Out:
#                   TURNSTILE        DATE  DAILY_ENTRIES
# 0  A002 R051 02-00-00 59 ST  03/17/2019          623.0
# 1  A002 R051 02-00-00 59 ST  03/18/2019         1382.0
# 2  A002 R051 02-00-00 59 ST  03/19/2019         1501.0
# 3  A002 R051 02-00-00 59 ST  03/20/2019         1583.0
# 4  A002 R051 02-00-00 59 ST  03/21/2019         1488.0

# %%
# Plotting one turnstile by day for 50 days

x = one_turn_daily['DATE'][:50]
y = one_turn_daily['DAILY_ENTRIES'][:50]

plt.figure(figsize=(15,3))
plt.plot(x, y)
plt.grid()
plt.xlabel('Date', size = 12)
plt.ylabel('Entries')
plt.xticks(rotation=45)
plt.title('Entries at {} turnstile'.format('"A002 R051 02-00-00 59 ST"'));

# %% [markdown]
# # Challenge 5

# %%
# Grouping by station


# turnstiles_daily.head()

# CA_U_S = turnstiles_daily.groupby(['C/A', 'UNIT', 'STATION', 'DATE']).sum()

CA_U_S = mta_daily.groupby(['C/A', 'UNIT', 'STATION', 'DATE'], as_index = False).sum()

CA_U_S.head()
# Out:
#     C/A  UNIT STATION        DATE   ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# 0  A002  R051   59 ST  03/17/2019  54633815    54627558.0         6257.0
# 1  A002  R051   59 ST  03/18/2019  54645862    54633815.0        12047.0
# 2  A002  R051   59 ST  03/19/2019  54658997    54645862.0        13135.0
# 3  A002  R051   59 ST  03/20/2019  54672404    54658997.0        13407.0
# 4  A002  R051   59 ST  03/21/2019  54685633    54672404.0        13229.0

# %% [markdown]
# # Challenge 6

# %%
# Grouping by station

# stations_daily = turnstiles_daily.groupby(['STATION', 'DATE']).sum()

stations_grouped_df = mta_daily.groupby(['STATION', 'DATE'], as_index = False).sum()

stations_grouped_df.head()
# Out:
#   STATION        DATE     ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# 0    1 AV  03/17/2019  1412586441  1.412586e+09            2.0
# 1    1 AV  03/18/2019  1412602582  1.412586e+09        16141.0
# 2    1 AV  03/19/2019  1412622097  1.412603e+09        19515.0
# 3    1 AV  03/20/2019  1412641982  1.412622e+09        19885.0
# 4    1 AV  03/21/2019  1412662466  1.412642e+09        20484.0

# %%
stations_grouped_df['STATION'].value_counts()
# Out:
# MT EDEN AV         97
# 79 ST              97
# LIVONIA AV         97
# HEWES ST           97
# 75 ST-ELDERTS      97
#                    ..
# NEW LOTS           94
# EASTCHSTER/DYRE    93
# 5 AVE              92
# ORCHARD BEACH      31
# ASTORIA BLVD        2
# Name: STATION, Length: 383, dtype: int64

# %% [markdown]
# # Challenge 7

# %%
# Extracting a single station

# mask = stations_grouped_df['STATION'] == '86 ST  R'  # Use this if station = station+line above

mask = stations_grouped_df['STATION'] == '1 AV'

one_station = stations_grouped_df[mask]

one_station.head()
# Out:
#   STATION        DATE     ENTRIES  PREV_ENTRIES  DAILY_ENTRIES
# 0    1 AV  03/17/2019  1412586441  1.412586e+09            2.0
# 1    1 AV  03/18/2019  1412602582  1.412586e+09        16141.0
# 2    1 AV  03/19/2019  1412622097  1.412603e+09        19515.0
# 3    1 AV  03/20/2019  1412641982  1.412622e+09        19885.0
# 4    1 AV  03/21/2019  1412662466  1.412642e+09        20484.0

# %%
# Plotting daily entries for one station

x = one_station['DATE'][:50]
y = one_station['DAILY_ENTRIES'][:50]

plt.figure(figsize=(15,3))
plt.grid()
plt.plot(x,y)
plt.xlabel('Date')
plt.ylabel('Daily entries')
# plt.title('Daily entries at "86 ST  R" Station over 50 days', size=15) # Use this if station = station+line above
plt.title('Daily entries at "1 AV" Station over 50 days', size=15)

plt.xticks(rotation=45);

# %% [markdown]
# # Challenge 8

# %%
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES                 TURNSTILE
# 1     6981415.0          623.0  A002 R051 02-00-00 59 ST
# 2     6982038.0         1382.0  A002 R051 02-00-00 59 ST
# 3     6983420.0         1501.0  A002 R051 02-00-00 59 ST
# 4     6984921.0         1583.0  A002 R051 02-00-00 59 ST
# 5     6986504.0         1488.0  A002 R051 02-00-00 59 ST

# %%
# Adding weekday column to mta_daily

mta_daily['WEEK_DAY'] = pd.to_datetime(mta_daily['DATE']).dt.dayofweek

mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  03/17/2019  6982038  03/16/2019
# 2  A002  R051  02-00-00   59 ST  03/18/2019  6983420  03/17/2019
# 3  A002  R051  02-00-00   59 ST  03/19/2019  6984921  03/18/2019
# 4  A002  R051  02-00-00   59 ST  03/20/2019  6986504  03/19/2019
# 5  A002  R051  02-00-00   59 ST  03/21/2019  6987992  03/20/2019
#
#    PREV_ENTRIES  DAILY_ENTRIES                 TURNSTILE  WEEK_DAY
# 1     6981415.0          623.0  A002 R051 02-00-00 59 ST         6
# 2     6982038.0         1382.0  A002 R051 02-00-00 59 ST         0
# 3     6983420.0         1501.0  A002 R051 02-00-00 59 ST         1
# 4     6984921.0         1583.0  A002 R051 02-00-00 59 ST         2
# 5     6986504.0         1488.0  A002 R051 02-00-00 59 ST         3

# %% [markdown]
# Desired: a list of frames; each having daily entries for 1 week

# %% [markdown]
# "Make one list of counts for one week for one station. Monday's count, Tuesday's count, etc. so it's a list of 7 counts. Make the same list for another week, and another week, and another week."

# %%
# Making a function to get entries by week

def get_week_list(input_frame, column_name, num_days):
    """
    Loops through dataframe and divides up desired column by increments of number of days (ex: 7 for a week)
    """
    window = 1   # starts at 1 because first day 0 is in second row
    week_list = []
    while window < len(input_frame)-num_days:  
        week_list.append(input_frame[column_name][window:window+num_days])  # do NOT double bracket daily entries. Will kill kernel
        window+=num_days
    return week_list

# %%
# Testing it

# input_frame = mta_daily[mta_daily['STATION'] == '86 ST  R'] # Use this if station = station+line above
input_frame = mta_daily[mta_daily['STATION'] == '1 AV']
column_name = 'DAILY_ENTRIES'
num_days = 7

get_week_list(input_frame, column_name, num_days)
# Out:
# [71644    1904.0
#  71645    3242.0
#  71646    3819.0
#  71647    4152.0
#  71648    4083.0
#  71649    2363.0
#  71650    1684.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  
0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72492    2587.0
#  72493    2661.0
#  72494    2579.0
#  72495    2617.0
#  72496    1981.0
#  72497    1596.0
#  72498    1435.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72499    2232.0
#  72500    2363.0
#  72501    2371.0
#  72502    2740.0
#  72503    2362.0
#  72504    1813.0
#  72505    2249.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72506    2265.0
#  72507    2653.0
#  72508    2599.0
#  72509    2845.0
#  72510    2352.0
#  72511    1681.0
#  72512    2100.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72513    2484.0
#  72514    2700.0
#  72515    2473.0
#  72516    2783.0
#  72517    2323.0
#  72518    1500.0
#  72519    2072.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72520    2175.0
#  72521    2342.0
#  72522    2405.0
#  72523    2603.0
#  72525       2.0
#  72526    2763.0
#  72527    3548.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72528    3918.0
#  72529    3672.0
#  72530    3743.0
#  72531    3235.0
#  72532    2974.0
#  72533    3507.0
#  72534    3544.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72535    3818.0
#  72536    3751.0
#  72537    4003.0
#  72538    3180.0
#  72539    3106.0
#  72540    3466.0
#  72541    4060.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72542    4560.0
#  72543    4123.0
#  72544    2582.0
#  72545    3130.0
#  72546    2295.0
#  72547    3629.0
#  72548    3436.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72549    4007.0
#  72550    4105.0
#  72551    3770.0
#  72552    3877.0
#  72553    3690.0
#  72554    3278.0
#  72555    4054.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72556    4504.0
#  72557    3862.0
#  72558    3299.0
#  72559    3072.0
#  72560    2651.0
#  72561    3037.0
#  72562    3104.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72563    3372.0
#  72564    3441.0
#  72565    3354.0
#  72566    2609.0
#  72567    2159.0
#  72568    3326.0
#  72569    2856.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72570    3173.0
#  72571    3373.0
#  72572    3925.0
#  72573    3057.0
#  72574    2351.0
#  72575    3386.0
#  72576    3771.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72577    3844.0
#  72578    4043.0
#  72579    3853.0
#  72580    3398.0
#  72581    2110.0
#  72582    3073.0
#  72583    3517.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72584    3739.0
#  72585    3911.0
#  72586    3442.0
#  72587    3182.0
#  72588    2478.0
#  72589    3049.0
#  72590    3840.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72591    3956.0
#  72592    3973.0
#  72593    3868.0
#  72594    2793.0
#  72595    2131.0
#  72596    2058.0
#  72597    3400.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72598    3726.0
#  72599    3757.0
#  72600    3798.0
#  72601    3285.0
#  72602    2640.0
#  72603    3489.0
#  72604    3501.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72605    3858.0
#  72606    3725.0
#  72607    4150.0
#  72608    3491.0
#  72609    2585.0
#  72610    3231.0
#  72611    3599.0
#  Name: DAILY_ENTRIES, dtype: float64,
#  72612    3942.0
#  72613    3807.0
#  72614    3993.0
#  72615    3299.0
#  72616    2375.0
#  72617    3228.0
#  72618    3430.0
#  Name: DAILY_ENTRIES, dtype: float64]

# %%
# viewing single entry

get_week_list(input_frame, column_name, num_days)[0]
# Out:
# 71644    1904.0
# 71645    3242.0
# 71646    3819.0
# 71647    4152.0
# 71648    4083.0
# 71649    2363.0
# 71650    1684.0
# Name: DAILY_ENTRIES, dtype: float64

# %%
# Plotting

x = np.arange(1,8) # weekdays from 1 to 7
weeks = get_week_list(input_frame, column_name, num_days)

plt.figure(figsize = (15, 5))
plt.xlabel('Week day')
plt.ylabel('Daily entries')
plt.title('Weekday vs daily entries')
for i in weeks[:5]:   # plotting 5 weeks for a single station
    legend_text = []
    plt.plot(x, i);
# plt.legend()

# %% [markdown]
# # Challenge 9
